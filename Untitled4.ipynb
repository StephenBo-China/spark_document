# %%
import utils
import numpy as np
import pandas as pd

# %%
def is_in_notebook():
    import sys
    return 'ipykernel' in sys.modules
def clear_output():
    """
    clear output for both jupyter notebook and the console
    """
    import os
    os.system('cls' if os.name == 'nt' else 'clear')
    if is_in_notebook():
        from IPython.display import clear_output as clear
        clear()

# %%
data_sql = utils.load_sql_file("./sql/xiefei.sql")
data_sql
# Out:
# "select\n    order_id,\n    bubble_trace_id,\n    concat_ws(',', collect_set(product_category)) as product_set,\n    count(distinct product_category) as pl_num\nfrom\n    (\n        select\n            order_id,\n            bubble_trace_id,\n            case\n                when sub_product_line = 9 then 'Luxury'\n                when sub_product_line in (1, 6)\n                and require_level in (100) then 'Premium'\n                when sub_product_line in (1, 6)\n                and require_level in (400) then 'CommercialPremium'\n                when sub_product_line in(3, 7, 314)\n                and require_level in (600)\n                and combo_type in (4)\n                and carpool_type in (1, 2) then 'Carpool'\n                when sub_product_line in (20, 99) then 'YouXiang'\n                when sub_product_line in (30) then 'APlusFlash'\n                when sub_product_line in (3, 7, 314)\n                and require_level in (600)\n                and combo_type in (314) then 'SpFlash'\n                when sub_product_line in (3, 7, 314)\n                and require_level in (600)\n                and combo_type in (0, 309, 306) then 'Flash'\n                when sub_product_line in (11, 12)\n                and require_level in (1100) then 'Unione'\n                when product_id in (1, 2)\n                and require_level in (200)\n                and combo_type in (0, 2, 3, 309)\n                and carpool_type in (0) then 'ExecutivePremium'\n                else 'Other'\n            end as product_category\n        from\n            decdm.dwd_ord_anycar_multi_di\n        where\n            dt >= '2020-12-01'\n            and dt <= '2020-12-07'\n        group by\n            order_id,\n            bubble_trace_id,\n            case\n                when sub_product_line = 9 then 'Luxury'\n                when sub_product_line in (1, 6)\n                and require_level in (100) then 'Premium'\n                when sub_product_line in (1, 6)\n                and require_level in (400) then 'CommercialPremium'\n                when sub_product_line in(3, 7, 314)\n                and require_level in (600)\n                and combo_type in (4)\n                and carpool_type in (1, 2) then 'Carpool'\n                when sub_product_line in (20, 99) then 'YouXiang'\n                when sub_product_line in (30) then 'APlusFlash'\n                when sub_product_line in (3, 7, 314)\n                and require_level in (600)\n                and combo_type in (314) then 'SpFlash'\n                when sub_product_line in (3, 7, 314)\n                and require_level in (600)\n                and combo_type in (0, 309, 306) then 'Flash'\n                when sub_product_line in (11, 12)\n                and require_level in (1100) then 'Unione'\n                when product_id in (1, 2)\n                and require_level in (200)\n                and combo_type in (0, 2, 3, 309)\n                and carpool_type in (0) then 'ExecutivePremium'\n                else 'Other'\n            end\n    ) multi\ngroup by\n    order_id,\n    bubble_trace_id"

# %%
data = spark.sql(data_sql)
data.cache()
data.head(5)
# Out:
# [Row(order_id=17705223126851, bubble_trace_id=u'c0a801055fc44dfb2cc15f4610100403', product_set=u'Other,SpFlash', pl_num=2),
#  Row(order_id=17705257091193, bubble_trace_id=u'6446aa145fc47b70b86f1a53549bcb02', product_set=u'APlusFlash,Flash,Unione', pl_num=3),
#  Row(order_id=17705361600391, bubble_trace_id=u'c0a803335fc505121906470f10810303', product_set=u'Premium', pl_num=1),
#  Row(order_id=17705362545380, bubble_trace_id=u'0aa44a125fc505ed00001be2d74ab795', product_set=u'Flash,YouXiang', pl_num=2),
#  Row(order_id=17705362728264, bubble_trace_id=u'6f01c10c5fc507ba031f171e10bd0303', product_set=u'Unione', pl_num=1)]

# %%
x = data.head(1)
x
# Out:
# [Row(order_id=17705223126851, bubble_trace_id=u'c0a801055fc44dfb2cc15f4610100403', product_set=u'Other,SpFlash', pl_num=2)]

# %%
data.columns
# Out:
# ['order_id', 'bubble_trace_id', 'product_set', 'pl_num']

# %%
def map_func(x):
    k, vv = x
    trace_id = k
    rst_key = ""
    for v in vv:
        product_set = sorted(v["product_set"].split(","))
        print(product_set)
        rst_key = ",".join([ x for x in product_set])
        print(rst_key)
    return [(rst_key, [1])]

# %%
map_func(("0003ff985fcb9c2f000052546db20735", x))
# Out:
# [u'Other', u'SpFlash']
# Other,SpFlash
# [(u'Other,SpFlash', [1])]

# %%
def reduce_func(v1, v2):
    print("RUN reduce_func")
    return list(map(sum, zip(v1, v2)))

# %%
reduce_func(
    [1],
    [1]
)
# Out:
# RUN reduce_func
# [2]

# %%
rst = data.rdd \
    .map(lambda x: (x["bubble_trace_id"], x)) \
    .groupByKey() \
    .flatMap(lambda x: map_func(x)) \
    .reduceByKey(reduce_func) \
    .collect()
rst
# Out:
# [(u'CommercialPremium,Luxury,Premium,Unione', [155]),
#  (u'Carpool,Luxury,Premium,SpFlash,Unione,YouXiang', [197]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Other,SpFlash,Unione,YouXiang',
#   [1]),
#  (u'CommercialPremium,Flash,Other,Premium,Unione,YouXiang', [1849]),
#  (u'CommercialPremium,Flash,Other,Premium,SpFlash,Unione', [287]),
#  (u'APlusFlash,Flash,Premium,YouXiang', [79073]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Luxury,Other,Premium,SpFlash,YouXiang',
#   [1]),
#  (u'CommercialPremium,Flash,Other,YouXiang', [250]),
#  (u'APlusFlash,Carpool,CommercialPremium,SpFlash', [35]),
#  (u'APlusFlash,Carpool,Luxury,YouXiang', [6]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Other,Premium,SpFlash,Unione',
#   [27]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Luxury,Other,Premium,Unione,YouXiang',
#   [1]),
#  (u'Carpool,CommercialPremium,Luxury,Premium,SpFlash', [6]),
#  (u'Carpool,Flash,Luxury,Other,SpFlash,Unione', [4]),
#  (u'APlusFlash,Flash,Luxury,Premium,Unione,YouXiang', [154]),
#  (u'CommercialPremium,Flash,Luxury,Premium', [158]),
#  (u'Flash,Other,Premium,SpFlash', [23596]),
#  (u'Carpool,CommercialPremium,Unione', [144]),
#  (u'APlusFlash,Carpool,Other,SpFlash,Unione', [59162]),
#  (u'CommercialPremium,Luxury,Unione', [32]),
#  (u'Flash,Other,Premium,Unione,YouXiang', [47493]),
#  (u'APlusFlash,CommercialPremium,Luxury,Premium,SpFlash,Unione', [1]),
#  (u'CommercialPremium,Other,Premium,SpFlash,Unione,YouXiang', [62]),
#  (u'SpFlash', [12934641]),
#  (u'CommercialPremium,Flash,Premium,SpFlash,YouXiang', [1179]),
#  (u'APlusFlash,Carpool,Other,Premium,SpFlash,Unione,YouXiang', [3716]),
#  (u'CommercialPremium,Luxury,Other,Premium,SpFlash,YouXiang', [2]),
#  (u'Carpool,CommercialPremium,Premium', [175]),
#  (u'APlusFlash,CommercialPremium,Other,Premium', [359]),
#  (u'APlusFlash,CommercialPremium,Flash,Other,Premium,SpFlash', [242]),
#  (u'APlusFlash,Carpool,Flash,Other,Premium,SpFlash,Unione', [437]),
#  (u'Carpool,CommercialPremium,Luxury,SpFlash,Unione,YouXiang', [2]),
#  (u'Carpool,Flash,Other,Premium,Unione,YouXiang', [3491]),
#  (u'CommercialPremium,SpFlash,Unione', [390]),
#  (u'APlusFlash,Carpool,Luxury,Other,Unione', [4]),
#  (u'Luxury,SpFlash,YouXiang', [26]),
#  (u'CommercialPremium,Luxury,Premium,SpFlash,YouXiang', [27]),
#  (u'Carpool,CommercialPremium,SpFlash,Unione,YouXiang', [28]),
#  (u'Carpool,CommercialPremium,Other,SpFlash', [101]),
#  (u'APlusFlash,Carpool,Premium,SpFlash,Unione', [2528]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Other,SpFlash,Unione', [10]),
#  (u'CommercialPremium,Flash,Other,SpFlash,YouXiang', [105]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Other,SpFlash,Unione', [1]),
#  (u'APlusFlash,Luxury,SpFlash', [10]),
#  (u'Carpool,CommercialPremium,Other,Premium,SpFlash,YouXiang', [22]),
#  (u'Luxury,Other,Unione,YouXiang', [15]),
#  (u'APlusFlash,Carpool,Luxury,Premium,YouXiang', [6]),
#  (u'Carpool,Other,Premium,SpFlash,YouXiang', [1643]),
#  (u'APlusFlash,SpFlash,Unione', [85529]),
#  (u'Carpool,Flash,YouXiang', [65564]),
#  (u'Carpool,CommercialPremium,Luxury,Other,Premium,SpFlash,Unione,YouXiang',
#   [86]),
#  (u'APlusFlash,Flash,Other,SpFlash', [396409]),
#  (u'Flash,Other,SpFlash,Unione,YouXiang', [146592]),
#  (u'APlusFlash,Luxury', [161]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Other,SpFlash,YouXiang', [1]),
#  (u'Flash,Luxury,Other,Premium,SpFlash,Unione', [5]),
#  (u'APlusFlash,Carpool,Flash', [93060]),
#  (u'APlusFlash,CommercialPremium,Flash,SpFlash,YouXiang', [118]),
#  (u'CommercialPremium,YouXiang', [2683]),
#  (u'APlusFlash,Carpool,Luxury,Other,Premium,SpFlash,Unione,YouXiang', [11]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Luxury,Other,Premium,Unione',
#   [2]),
#  (u'Unione,YouXiang', [253422]),
#  (u'CommercialPremium,Luxury,YouXiang', [41]),
#  (u'CommercialPremium,Flash,Luxury,Other,Premium,SpFlash', [14]),
#  (u'Luxury,Premium,SpFlash,Unione', [28]),
#  (u'CommercialPremium,Luxury,Other,Unione', [5]),
#  (u'Carpool,CommercialPremium,YouXiang', [77]),
#  (u'CommercialPremium,Luxury,SpFlash,YouXiang', [2]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Premium,Unione,YouXiang', [8]),
#  (u'Carpool,CommercialPremium,Luxury,Other,Premium,SpFlash,Unione', [6]),
#  (u'Carpool,CommercialPremium,Flash,Other,Unione', [2]),
#  (u'APlusFlash,CommercialPremium,Flash,SpFlash,Unione,YouXiang', [182]),
#  (u'APlusFlash,Luxury,SpFlash,Unione,YouXiang', [1]),
#  (u'Luxury,SpFlash', [577]),
#  (u'APlusFlash,Premium,Unione,YouXiang', [15280]),
#  (u'Carpool,Flash,Luxury,Unione,YouXiang', [96]),
#  (u'Carpool,CommercialPremium,Flash,Luxury,Other,SpFlash,Unione,YouXiang',
#   [1]),
#  (u'CommercialPremium,Flash,Luxury,Other,SpFlash,YouXiang', [1]),
#  (u'Premium,SpFlash,YouXiang', [15148]),
#  (u'APlusFlash,CommercialPremium,Other', [99]),
#  (u'APlusFlash,Flash,Other,Premium,SpFlash', [12832]),
#  (u'Flash,Luxury,Other,SpFlash,YouXiang', [20]),
#  (u'APlusFlash,CommercialPremium,Luxury,Other,Premium', [4]),
#  (u'APlusFlash,Carpool,Luxury,Other,Premium,YouXiang', [3]),
#  (u'Carpool,Flash,Other,SpFlash', [24196]),
#  (u'APlusFlash,Carpool,Flash,Other,Unione', [23375]),
#  (u'Carpool,CommercialPremium,Luxury', [8]),
#  (u'Flash,Unione,YouXiang', [1880065]),
#  (u'CommercialPremium,Flash,SpFlash,Unione', [818]),
#  (u'APlusFlash,Carpool,CommercialPremium,Other,Premium,Unione', [62]),
#  (u'Luxury,Other,Premium,SpFlash,Unione,YouXiang', [3]),
#  (u'Carpool,Flash,Premium,Unione', [2962]),
#  (u'APlusFlash,Flash,Luxury,SpFlash,Unione,YouXiang', [3]),
#  (u'APlusFlash,CommercialPremium,Luxury,Premium', [109]),
#  (u'Carpool,Other,Premium,SpFlash,Unione', [2327]),
#  (u'Luxury,Other,Premium,SpFlash', [11]),
#  (u'Carpool,Luxury,YouXiang', [40]),
#  (u'APlusFlash,Carpool,CommercialPremium,Luxury,Premium,Unione', [1]),
#  (u'APlusFlash,Carpool,Luxury,SpFlash,YouXiang', [2]),
#  (u'APlusFlash,Flash,Luxury,Other,Unione', [35]),
#  (u'Carpool,CommercialPremium,Premium,SpFlash,Unione,YouXiang', [240]),
#  (u'Luxury,Premium', [11354]),
#  (u'APlusFlash,Carpool,Other', [43921]),
#  (u'APlusFlash,Luxury,Other,SpFlash,YouXiang', [1]),
#  (u'APlusFlash,Carpool,CommercialPremium,Luxury,Other,SpFlash,Unione', [2]),
#  (u'CommercialPremium,Other,Premium,Unione', [206]),
#  (u'Carpool,Flash,Luxury,SpFlash', [38]),
#  (u'CommercialPremium,Flash,Other,Unione', [163]),
#  (u'Flash,Luxury,Other,Unione', [96]),
#  (u'Other,Premium,Unione', [7052]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Unione,YouXiang', [4]),
#  (u'CommercialPremium,Other,Premium,SpFlash,YouXiang', [70]),
#  (u'APlusFlash,Carpool,CommercialPremium,Premium,Unione', [32]),
#  (u'APlusFlash,Premium,SpFlash,YouXiang', [4186]),
#  (u'APlusFlash,Carpool,Flash,Premium,SpFlash,YouXiang', [401]),
#  (u'APlusFlash,Luxury,Premium,YouXiang', [201]),
#  (u'Luxury,Other,Premium,Unione,YouXiang', [64]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Premium,SpFlash,Unione,YouXiang',
#   [5]),
#  (u'APlusFlash,Other,Premium,SpFlash,Unione', [1790]),
#  (u'APlusFlash,CommercialPremium,Flash,Other,Premium,Unione', [365]),
#  (u'APlusFlash,CommercialPremium,Flash,SpFlash,Unione', [312]),
#  (u'APlusFlash,CommercialPremium,Premium,SpFlash,YouXiang', [72]),
#  (u'CommercialPremium,Luxury,Premium', [4187]),
#  (u'Carpool,CommercialPremium,Flash', [21]),
#  (u'CommercialPremium,Flash,Luxury,SpFlash', [19]),
#  (u'APlusFlash,Carpool,SpFlash', [206488]),
#  (u'Carpool,Flash,Luxury,Other,Premium,YouXiang', [2]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,SpFlash,YouXiang', [2]),
#  (u'Carpool,Flash,Premium,SpFlash,Unione,YouXiang', [8785]),
#  (u'APlusFlash,Other,YouXiang', [9611]),
#  (u'Carpool,CommercialPremium,Luxury,SpFlash', [3]),
#  (u'APlusFlash,Flash,Other,Unione', [302859]),
#  (u'APlusFlash,CommercialPremium,Flash,Premium,Unione', [526]),
#  (u'Luxury,Premium,SpFlash,Unione,YouXiang', [68]),
#  (u'Carpool,CommercialPremium,Other,SpFlash,Unione,YouXiang', [33]),
#  (u'APlusFlash,Carpool,CommercialPremium,Other,SpFlash,Unione,YouXiang', [25]),
#  (u'Carpool,CommercialPremium,Premium,SpFlash,Unione', [42]),
#  (u'APlusFlash,CommercialPremium,Flash,YouXiang', [318]),
#  (u'APlusFlash,Carpool,CommercialPremium,Premium,YouXiang', [16]),
#  (u'Luxury,Other,SpFlash,YouXiang', [3]),
#  (u'APlusFlash,Luxury,YouXiang', [31]),
#  (u'APlusFlash,Carpool,CommercialPremium,Other,SpFlash,YouXiang', [4]),
#  (u'Carpool,CommercialPremium,Other,Unione,YouXiang', [10]),
#  (u'Flash,Unione', [8547547]),
#  (u'Carpool,CommercialPremium,Other', [37]),
#  (u'APlusFlash,Other,Premium,SpFlash', [3131]),
#  (u'APlusFlash,CommercialPremium,Other,SpFlash,YouXiang', [12]),
#  (u'Carpool,CommercialPremium,Luxury,Other,Premium,YouXiang', [1]),
#  (u'Other,SpFlash,Unione', [305336]),
#  (u'Flash,Other,YouXiang', [255519]),
#  (u'Flash,Other', [1403482]),
#  (u'APlusFlash,CommercialPremium,Flash,Other,Premium,SpFlash,Unione,YouXiang',
#   [2069]),
#  (u'APlusFlash,Other,SpFlash,Unione', [28963]),
#  (u'CommercialPremium,Luxury,SpFlash', [34]),
#  (u'Flash,Luxury,Other,SpFlash,Unione,YouXiang', [59]),
#  (u'APlusFlash,Carpool,Flash,Luxury,Other,Premium,Unione,YouXiang', [6]),
#  (u'APlusFlash,Premium,YouXiang', [36086]),
#  (u'APlusFlash,Luxury,Premium,SpFlash', [14]),
#  (u'APlusFlash,Flash,Luxury,Other,SpFlash,YouXiang', [1]),
#  (u'APlusFlash,Carpool,CommercialPremium,Premium', [47]),
#  (u'Other,Premium', [37295]),
#  (u'APlusFlash,Premium,SpFlash', [9407]),
#  (u'APlusFlash,Carpool,Unione,YouXiang', [22847]),
#  (u'Carpool,CommercialPremium,Flash,Unione,YouXiang', [11]),
#  (u'APlusFlash,CommercialPremium,Other,Premium,YouXiang', [178]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Other,Premium,Unione,YouXiang',
#   [15]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Premium,YouXiang', [1]),
#  (u'APlusFlash,Luxury,Other,Unione', [11]),
#  (u'Carpool,CommercialPremium,Luxury,Premium,SpFlash,YouXiang', [3]),
#  (u'APlusFlash,Flash,Other', [319863]),
#  (u'APlusFlash,CommercialPremium,Luxury,Other,Premium,Unione,YouXiang', [10]),
#  (u'Carpool,Luxury,SpFlash,Unione,YouXiang', [62]),
#  (u'APlusFlash,Carpool,CommercialPremium,Other,Premium,SpFlash,YouXiang',
#   [40]),
#  (u'APlusFlash,Carpool,CommercialPremium,Other,SpFlash,Unione', [36]),
#  (u'APlusFlash,CommercialPremium,Luxury,SpFlash', [2]),
#  (u'APlusFlash,Carpool,CommercialPremium,Luxury,Unione', [1]),
#  (u'APlusFlash,Flash,Luxury,Premium,SpFlash,Unione,YouXiang', [44]),
#  (u'APlusFlash,Flash,YouXiang', [509618]),
#  (u'Carpool,Other,Premium,Unione,YouXiang', [4046]),
#  (u'Carpool,Flash,Unione,YouXiang', [62622]),
#  (u'Carpool,YouXiang', [182368]),
#  (u'Carpool,Flash,SpFlash,Unione', [71050]),
#  (u'CommercialPremium,Premium,Unione', [2018]),
#  (u'APlusFlash,CommercialPremium', [1158]),
#  (u'APlusFlash,CommercialPremium,Other,Premium,Unione', [146]),
#  (u'APlusFlash,Carpool,Other,Premium,YouXiang', [682]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Other,Premium,SpFlash,Unione,YouXiang',
#   [23]),
#  (u'Carpool,Premium,YouXiang', [10707]),
#  (u'Carpool,Luxury,Unione', [53]),
#  (u'APlusFlash,Carpool,Premium,YouXiang', [2662]),
#  (u'APlusFlash,Carpool,Luxury,Premium,Unione,YouXiang', [8]),
#  (u'Carpool,Other,Premium,SpFlash', [5209]),
#  (u'Flash,Luxury,Unione,YouXiang', [649]),
#  (u'Carpool,CommercialPremium,Premium,YouXiang', [71]),
#  (u'Carpool,SpFlash', [2276897]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Luxury,Other,Premium,SpFlash,Unione,YouXiang',
#   [2]),
#  (u'Other', [1115767]),
#  (u'Carpool,Flash,Premium,SpFlash,YouXiang', [2085]),
#  (u'Other,Premium,Unione,YouXiang', [6579]),
#  (u'Luxury,Other,Premium,SpFlash,Unione', [3]),
#  (u'Carpool,Flash,Luxury,Premium,SpFlash', [10]),
#  (u'CommercialPremium,Flash', [18846]),
#  (u'Carpool,CommercialPremium,Flash,SpFlash,Unione', [2]),
#  (u'APlusFlash,SpFlash,Unione,YouXiang', [6861]),
#  (u'APlusFlash,Luxury,Other,Premium,SpFlash,Unione,YouXiang', [2]),
#  (u'Carpool,Luxury,Premium', [53]),
#  (u'Carpool,Luxury,Other,Unione,YouXiang', [6]),
#  (u'Carpool,Other,SpFlash,Unione,YouXiang', [29200]),
#  (u'APlusFlash,Carpool,Luxury,Unione', [8]),
#  (u'APlusFlash,Flash,Other,YouXiang', [82008]),
#  (u'APlusFlash,CommercialPremium,Flash,Other,Unione', [79]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Other,Premium,Unione,YouXiang',
#   [76]),
#  (u'APlusFlash,Carpool,CommercialPremium,Unione,YouXiang', [13]),
#  (u'APlusFlash,Luxury,Premium,Unione,YouXiang', [68]),
#  (u'APlusFlash,Carpool,CommercialPremium,Other,Premium,SpFlash', [26]),
#  (u'APlusFlash,SpFlash,YouXiang', [18231]),
#  (u'CommercialPremium,Other,Premium,Unione,YouXiang', [272]),
#  (u'Carpool', [5638459]),
#  (u'APlusFlash,Premium', [50062]),
#  (u'APlusFlash,Premium,Unione', [13388]),
#  (u'Carpool,Premium,SpFlash,YouXiang', [6320]),
#  (u'CommercialPremium,Flash,Luxury,Other,Premium,YouXiang', [1110]),
#  (u'Carpool,Premium,Unione,YouXiang', [17121]),
#  (u'APlusFlash,CommercialPremium,Flash,Other,SpFlash,Unione,YouXiang', [206]),
#  (u'Carpool,Flash,Other,SpFlash,Unione,YouXiang', [7276]),
#  (u'APlusFlash,Luxury,Unione,YouXiang', [3]),
#  (u'Carpool,Luxury,Other,Premium,Unione', [20]),
#  (u'APlusFlash,CommercialPremium,Luxury', [11]),
#  (u'Carpool,Unione,YouXiang', [141246]),
#  (u'APlusFlash,Carpool', [351701]),
#  (u'APlusFlash,Luxury,SpFlash,Unione', [8]),
#  (u'APlusFlash,CommercialPremium,Premium,SpFlash', [78]),
#  (u'CommercialPremium,Flash,Luxury,Other,Premium', [15]),
#  (u'CommercialPremium,Other,Unione', [148]),
#  (u'Carpool,Luxury,SpFlash', [72]),
#  (u'Carpool,Premium', [34886]),
#  (u'Carpool,Luxury', [140]),
#  (u'Carpool,Luxury,Other,YouXiang', [4]),
#  (u'APlusFlash,Other,Premium', [3864]),
#  (u'APlusFlash,Carpool,Flash,Other,YouXiang', [1315]),
#  (u'APlusFlash,Carpool,Flash,Premium,YouXiang', [1065]),
#  (u'APlusFlash,CommercialPremium,Other,Premium,SpFlash,Unione', [117]),
#  (u'APlusFlash,Unione', [236592]),
#  (u'APlusFlash,SpFlash', [480330]),
#  (u'APlusFlash,Flash,Premium', [92977]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Premium,Unione,YouXiang', [31]),
#  (u'Carpool,Flash,Luxury,SpFlash,Unione', [21]),
#  (u'APlusFlash,Carpool,Other,SpFlash,Unione,YouXiang', [12965]),
#  (u'APlusFlash,Flash,Unione,YouXiang', [324419]),
#  (u'APlusFlash,CommercialPremium,Luxury,Other,Premium,Unione', [11]),
#  (u'APlusFlash,CommercialPremium,Luxury,YouXiang', [2]),
#  (u'Carpool,CommercialPremium,Flash,Other,Premium,YouXiang', [2]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,SpFlash,Unione,YouXiang', [2]),
#  (u'Flash,Premium', [513915]),
#  (u'APlusFlash,Carpool,Luxury,Other', [3]),
#  (u'CommercialPremium,Flash,Luxury,Other,SpFlash,Unione,YouXiang', [5]),
#  (u'Carpool,Other,SpFlash,Unione', [138751]),
#  (u'CommercialPremium,Flash,Unione', [1878]),
#  (u'Flash,Luxury,Other,Premium,SpFlash', [9]),
#  (u'APlusFlash,Flash,SpFlash', [1715703]),
#  (u'CommercialPremium,Flash,Other,Premium', [943]),
#  (u'APlusFlash,Flash,Luxury,Other', [30]),
#  (u'Flash,Other,Premium,SpFlash,YouXiang', [13827]),
#  (u'Carpool,CommercialPremium,Other,Premium,YouXiang', [9]),
#  (u'Flash,Luxury', [2138]),
#  (u'APlusFlash,CommercialPremium,Premium,SpFlash,Unione', [42]),
#  (u'CommercialPremium,Premium', [53726]),
#  (u'Flash,Luxury,Other,Premium,YouXiang', [163]),
#  (u'Carpool,Luxury,Other,SpFlash,Unione,YouXiang', [15]),
#  (u'APlusFlash,CommercialPremium,Luxury,Premium,SpFlash', [6]),
#  (u'Carpool,Luxury,Premium,Unione,YouXiang', [270]),
#  (u'APlusFlash,Other,Unione,YouXiang', [7004]),
#  (u'CommercialPremium,Flash,Other,SpFlash,Unione', [308]),
#  (u'Flash,Premium,SpFlash', [97529]),
#  (u'Premium,Unione,YouXiang', [91267]),
#  (u'Carpool,CommercialPremium,Flash,Other,SpFlash,Unione,YouXiang', [1]),
#  (u'APlusFlash,CommercialPremium,Premium,SpFlash,Unione,YouXiang', [46]),
#  (u'CommercialPremium,Flash,Luxury,Other,Premium,Unione', [22]),
#  (u'APlusFlash,CommercialPremium,Flash,Other,Premium,Unione,YouXiang', [667]),
#  (u'CommercialPremium,SpFlash,YouXiang', [199]),
#  (u'APlusFlash,Carpool,Luxury,Unione,YouXiang', [1]),
#  (u'APlusFlash', [1226675]),
#  (u'APlusFlash,CommercialPremium,Other,Premium,SpFlash,YouXiang', [43]),
#  (u'CommercialPremium,Flash,Luxury,Other', [7]),
#  (u'Flash,Luxury,Other,Premium,SpFlash,Unione,YouXiang', [212]),
#  (u'Carpool,Flash,Luxury,Other,Unione,YouXiang', [11]),
#  (u'APlusFlash,CommercialPremium,SpFlash', [242]),
#  (u'APlusFlash,Flash,Luxury,Other,Premium', [45]),
#  (u'CommercialPremium,Luxury,Other,SpFlash,Unione,YouXiang', [2]),
#  (u'APlusFlash,CommercialPremium,Luxury,Premium,YouXiang', [43]),
#  (u'APlusFlash,Flash,Other,Premium,SpFlash,Unione,YouXiang', [24447]),
#  (u'Carpool,Other,SpFlash,YouXiang', [28742]),
#  (u'APlusFlash,Flash,Unione', [2179280]),
#  (u'CommercialPremium,Flash,Luxury,Unione,YouXiang', [14]),
#  (u'APlusFlash,CommercialPremium,Unione,YouXiang', [59]),
#  (u'APlusFlash,Luxury,Other,SpFlash', [2]),
#  (u'APlusFlash,Carpool,Luxury,Other,Premium,SpFlash,YouXiang', [1]),
#  (u'APlusFlash,Flash,Luxury,Premium,SpFlash,YouXiang', [14]),
#  (u'APlusFlash,Flash,Luxury,Other,Premium,SpFlash', [11]),
#  (u'Carpool,CommercialPremium,Flash,SpFlash,YouXiang', [2]),
#  (u'Other,SpFlash,YouXiang', [43191]),
#  (u'Carpool,Premium,SpFlash,Unione,YouXiang', [10333]),
#  (u'Other,Premium,SpFlash,Unione,YouXiang', [1378]),
#  (u'Carpool,CommercialPremium,Luxury,Other,Premium,SpFlash', [1]),
#  (u'APlusFlash,Flash,Other,Premium,Unione,YouXiang', [36071]),
#  (u'Carpool,Flash,SpFlash,YouXiang', [15165]),
#  (u'Carpool,CommercialPremium,Flash,Premium,SpFlash,Unione', [1]),
#  (u'Carpool,Flash,Luxury,Other,Premium,Unione', [4]),
#  (u'APlusFlash,Carpool,CommercialPremium,SpFlash,Unione', [28]),
#  (u'APlusFlash,Carpool,Flash,Luxury,Other,Premium,Unione', [10]),
#  (u'APlusFlash,Carpool,Flash,Other,Premium,YouXiang', [480]),
#  (u'Luxury,Premium,SpFlash', [88]),
#  (u'APlusFlash,CommercialPremium,Luxury,Premium,Unione,YouXiang', [16]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Premium,SpFlash,YouXiang', [19]),
#  (u'Luxury,Unione', [490]),
#  (u'Luxury', [34831]),
#  (u'Carpool,Flash,Other,Premium,SpFlash,YouXiang', [385]),
#  (u'Carpool,CommercialPremium,Luxury,Other,Premium,SpFlash,YouXiang', [3]),
#  (u'Flash,Other,Unione,YouXiang', [317279]),
#  (u'APlusFlash,Carpool,CommercialPremium,Luxury,Premium,SpFlash', [3]),
#  (u'APlusFlash,Carpool,Other,Premium,SpFlash,Unione', [2951]),
#  (u'Carpool,Flash,Premium,SpFlash', [648]),
#  (u'APlusFlash,Luxury,Unione', [27]),
#  (u'Carpool,Luxury,Unione,YouXiang', [68]),
#  (u'APlusFlash,Carpool,Flash,Premium,SpFlash', [265]),
#  (u'APlusFlash,Flash,Luxury,SpFlash,Unione', [20]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Other,Premium,YouXiang', [7]),
#  (u'CommercialPremium,Flash,Luxury,Premium,SpFlash,Unione', [49]),
#  (u'Carpool,SpFlash,Unione', [358195]),
#  (u'APlusFlash,CommercialPremium,Luxury,Premium,SpFlash,Unione,YouXiang',
#   [10]),
#  (u'APlusFlash,Flash,SpFlash,Unione', [901375]),
#  (u'Flash,SpFlash,YouXiang', [786709]),
#  (u'Carpool,CommercialPremium,Luxury,Unione,YouXiang', [2]),
#  (u'APlusFlash,CommercialPremium,Premium,YouXiang', [657]),
#  (u'APlusFlash,Carpool,Flash,SpFlash,Unione', [42487]),
#  (u'APlusFlash,Carpool,CommercialPremium,Other', [1]),
#  (u'Carpool,CommercialPremium,Other,SpFlash,Unione', [31]),
#  (u'APlusFlash,Carpool,CommercialPremium,Other,Premium,SpFlash,Unione,YouXiang',
#   [325]),
#  (u'APlusFlash,Carpool,Luxury,Premium,SpFlash', [1]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Premium', [39]),
#  (u'Flash,Luxury,Premium,Unione,YouXiang', [3202]),
#  (u'Carpool,CommercialPremium,Other,Premium', [15]),
#  (u'APlusFlash,Flash,Luxury', [155]),
#  (u'CommercialPremium,Luxury,Other,Premium', [45]),
#  (u'APlusFlash,Carpool,Luxury,Premium,SpFlash,Unione', [1]),
#  (u'APlusFlash,Carpool,Other,Premium,Unione', [2813]),
#  (u'Carpool,Luxury,Other,Premium', [2]),
#  (u'APlusFlash,Luxury,SpFlash,YouXiang', [1]),
#  (u'Flash,Luxury,Premium,SpFlash,YouXiang', [367]),
#  (u'Carpool,Flash,Luxury,Other,YouXiang', [5]),
#  (u'Carpool,Luxury,SpFlash,YouXiang', [35]),
#  (u'Flash,Other,Premium,YouXiang', [36082]),
#  (u'Carpool,Flash,Luxury,SpFlash,Unione,YouXiang', [74]),
#  (u'CommercialPremium,Flash,Unione,YouXiang', [922]),
#  (u'CommercialPremium,Flash,Other,Premium,Unione', [321]),
#  (u'CommercialPremium,Flash,Luxury,SpFlash,Unione', [3]),
#  (u'APlusFlash,Carpool,Flash,Other', [8428]),
#  (u'Carpool,CommercialPremium,Luxury,Premium,Unione,YouXiang', [12]),
#  (u'Other,SpFlash', [1760145]),
#  (u'APlusFlash,CommercialPremium,Flash,Other,Premium', [215]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Premium,YouXiang', [67]),
#  (u'Carpool,Other,Unione,YouXiang', [37730]),
#  (u'CommercialPremium,Flash,Other,Premium,SpFlash', [172]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Premium,SpFlash,Unione', [21]),
#  (u'Luxury,Premium,YouXiang', [1984]),
#  (u'CommercialPremium,Premium,SpFlash,Unione,YouXiang', [195]),
#  (u'CommercialPremium,Flash,Other,SpFlash', [730]),
#  (u'Flash,Other,SpFlash,YouXiang', [151910]),
#  (u'Carpool,CommercialPremium,Flash,Other,Premium,Unione', [1]),
#  (u'APlusFlash,CommercialPremium,Flash,Other,SpFlash,Unione', [252]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Premium,Unione', [7]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Other,Premium,SpFlash', [15]),
#  (u'APlusFlash,Carpool,Luxury,Premium,SpFlash,Unione,YouXiang', [6]),
#  (u'Flash,Luxury,Premium', [866]),
#  (u'CommercialPremium,Flash,Luxury,SpFlash,YouXiang', [3]),
#  (u'APlusFlash,Carpool,Flash,YouXiang', [4286]),
#  (u'Flash,Luxury,SpFlash,YouXiang', [167]),
#  (u'CommercialPremium,Flash,Luxury,YouXiang', [21]),
#  (u'Carpool,Flash,Luxury,Premium,SpFlash,Unione', [11]),
#  (u'APlusFlash,Carpool,CommercialPremium,Premium,SpFlash', [7]),
#  (u'APlusFlash,Flash', [5265354]),
#  (u'APlusFlash,Flash,Luxury,Other,Premium,Unione', [264]),
#  (u'Carpool,CommercialPremium,Premium,SpFlash,YouXiang', [53]),
#  (u'APlusFlash,Carpool,Flash,Other,Premium,SpFlash', [82]),
#  (u'Carpool,Flash,Luxury,Other,Premium,SpFlash,Unione,YouXiang', [55]),
#  (u'Carpool,CommercialPremium,Luxury,Premium,Unione', [2]),
#  (u'Carpool,Other,Premium,SpFlash,Unione,YouXiang', [4775]),
#  (u'Premium,SpFlash', [124749]),
#  (u'Carpool,Luxury,Other,Premium,YouXiang', [3]),
#  (u'Carpool,Flash,Other,Premium', [291]),
#  (u'APlusFlash,CommercialPremium,Premium,Unione,YouXiang', [236]),
#  (u'Other,Premium,SpFlash', [28430]),
#  (u'APlusFlash,Other,Premium,Unione', [2423]),
#  (u'APlusFlash,Luxury,Other,Premium,SpFlash,Unione', [2]),
#  (u'APlusFlash,Flash,Other,Premium,YouXiang', [13153]),
#  (u'Carpool,Other', [332816]),
#  (u'APlusFlash,Flash,Luxury,Unione,YouXiang', [36]),
#  (u'APlusFlash,CommercialPremium,Other,Unione', [46]),
#  (u'APlusFlash,Flash,Luxury,Unione', [48]),
#  (u'APlusFlash,CommercialPremium,Flash,Premium', [722]),
#  (u'CommercialPremium,Flash,Luxury', [107]),
#  (u'CommercialPremium,Flash,SpFlash,YouXiang', [582]),
#  (u'Other,Unione', [280424]),
#  (u'Carpool,Premium,SpFlash', [13867]),
#  (u'Flash,Luxury,Premium,YouXiang', [1575]),
#  (u'APlusFlash,Carpool,Premium,Unione', [5232]),
#  (u'APlusFlash,CommercialPremium,Flash,SpFlash', [486]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Other,Premium,SpFlash,Unione,YouXiang',
#   [171]),
#  (u'Carpool,CommercialPremium,Luxury,YouXiang', [4]),
#  (u'Carpool,CommercialPremium,Flash,Premium,SpFlash,Unione,YouXiang', [44]),
#  (u'APlusFlash,Luxury,Other,Premium', [25]),
#  (u'Carpool,Premium,Unione', [7598]),
#  (u'APlusFlash,Carpool,Other,SpFlash', [69939]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Premium,Unione', [22]),
#  (u'Carpool,CommercialPremium,Luxury,Premium', [6]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,YouXiang', [4]),
#  (u'APlusFlash,Carpool,Flash,Other,Premium,SpFlash,Unione,YouXiang', [992]),
#  (u'CommercialPremium,Luxury,Other,Premium,SpFlash,Unione', [3]),
#  (u'APlusFlash,Carpool,Other,Premium', [1339]),
#  (u'APlusFlash,Carpool,Other,Premium,SpFlash', [1440]),
#  (u'APlusFlash,CommercialPremium,SpFlash,Unione,YouXiang', [10]),
#  (u'APlusFlash,Flash,Premium,SpFlash,Unione', [21126]),
#  (u'APlusFlash,CommercialPremium,Flash,Premium,SpFlash,Unione', [436]),
#  (u'Carpool,Luxury,Premium,Unione', [25]),
#  (u'Flash,Premium,SpFlash,YouXiang', [90266]),
#  (u'Carpool,Flash,Other,SpFlash,Unione', [14173]),
#  (u'APlusFlash,CommercialPremium,Flash,Premium,Unione,YouXiang', [477]),
#  (u'Luxury,Other,Premium,YouXiang', [104]),
#  (u'Carpool,CommercialPremium,Premium,Unione,YouXiang', [99]),
#  (u'CommercialPremium,SpFlash', [7627]),
#  (u'Flash,Other,Premium,SpFlash,Unione,YouXiang', [28380]),
#  (u'Carpool,CommercialPremium,Flash,Other,SpFlash,Unione', [1]),
#  (u'APlusFlash,Luxury,Other,Premium,Unione', [5]),
#  (u'CommercialPremium,Flash,Other,Premium,YouXiang', [3787]),
#  (u'Flash,Other,Premium,SpFlash,Unione', [12366]),
#  (u'APlusFlash,Carpool,Other,Premium,SpFlash,YouXiang', [713]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,SpFlash,Unione,YouXiang', [3]),
#  (u'CommercialPremium,Other,SpFlash,YouXiang', [37]),
#  (u'APlusFlash,Flash,Other,Premium,SpFlash,YouXiang', [9031]),
#  (u'Carpool,CommercialPremium,Flash,Premium,Unione,YouXiang', [35]),
#  (u'APlusFlash,Carpool,Flash,Other,Premium,SpFlash,YouXiang', [178]),
#  (u'CommercialPremium,Flash,SpFlash,Unione,YouXiang', [421]),
#  (u'CommercialPremium,Premium,Unione,YouXiang', [1578]),
#  (u'APlusFlash,CommercialPremium,Luxury,Other,SpFlash', [1]),
#  (u'APlusFlash,Other,Premium,YouXiang', [5102]),
#  (u'APlusFlash,CommercialPremium,Other,Unione,YouXiang', [13]),
#  (u'APlusFlash,Carpool,CommercialPremium,Luxury,Other,Premium,Unione', [6]),
#  (u'APlusFlash,Flash,Luxury,Other,Premium,Unione,YouXiang', [428]),
#  (u'Other,Premium,SpFlash,YouXiang', [2970]),
#  (u'Luxury,Other,SpFlash', [40]),
#  (u'Carpool,CommercialPremium,Other,Premium,Unione', [13]),
#  (u'APlusFlash,Carpool,Flash,Luxury,Premium,Unione,YouXiang', [2]),
#  (u'Carpool,CommercialPremium,Other,YouXiang', [3]),
#  (u'Carpool,CommercialPremium,Flash,Luxury,Premium', [1]),
#  (u'Carpool,Flash,Premium', [2024]),
#  (u'CommercialPremium,Flash,Premium,Unione', [728]),
#  (u'Carpool,Flash,Other,Premium,SpFlash', [186]),
#  (u'APlusFlash,Carpool,Other,YouXiang', [7059]),
#  (u'Carpool,Luxury,Other,SpFlash,YouXiang', [9]),
#  (u'APlusFlash,Flash,Premium,SpFlash', [34244]),
#  (u'CommercialPremium,Other,Premium,SpFlash,Unione', [65]),
#  (u'CommercialPremium,Other', [2662]),
#  (u'APlusFlash,Carpool,Other,Unione,YouXiang', [14824]),
#  (u'APlusFlash,Flash,Luxury,Premium,SpFlash,Unione', [8]),
#  (u'Flash,Premium,Unione', [101986]),
#  (u'APlusFlash,CommercialPremium,Flash,Unione,YouXiang', [189]),
#  (u'Carpool,CommercialPremium', [1272]),
#  (u'APlusFlash,Carpool,CommercialPremium,Other,Unione,YouXiang', [3]),
#  (u'APlusFlash,Flash,SpFlash,YouXiang', [179670]),
#  (u'CommercialPremium,Luxury', [3192]),
#  (u'APlusFlash,Carpool,Other,Premium,Unione,YouXiang', [3861]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Other,Premium,YouXiang', [3]),
#  (u'Carpool,CommercialPremium,SpFlash', [449]),
#  (u'CommercialPremium,Other,SpFlash', [1173]),
#  (u'APlusFlash,CommercialPremium,Flash,Other,Premium,SpFlash,Unione', [1380]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Unione,YouXiang', [1]),
#  (u'CommercialPremium,Unione,YouXiang', [316]),
#  (u'CommercialPremium,Flash,Other,SpFlash,Unione,YouXiang', [237]),
#  (u'Carpool,CommercialPremium,Flash,SpFlash', [5]),
#  (u'SpFlash,Unione', [1028216]),
#  (u'CommercialPremium,Unione', [3454]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Other,Premium,SpFlash,YouXiang',
#   [19]),
#  (u'APlusFlash,Carpool,Flash,Other,Premium', [108]),
#  (u'Luxury,Other,Premium,Unione', [20]),
#  (u'Premium', [2001941]),
#  (u'APlusFlash,Carpool,Premium,Unione,YouXiang', [4899]),
#  (u'APlusFlash,CommercialPremium,Luxury,Other,Premium,SpFlash,Unione', [13]),
#  (u'APlusFlash,Flash,Luxury,Other,SpFlash,Unione', [6]),
#  (u'CommercialPremium,Flash,Other', [512]),
#  (u'APlusFlash,Flash,Luxury,Premium,SpFlash', [33]),
#  (u'APlusFlash,CommercialPremium,Flash,Other,SpFlash,YouXiang', [69]),
#  (u'APlusFlash,Flash,Other,Premium,SpFlash,Unione', [16509]),
#  (u'Carpool,Flash,Other,Premium,Unione', [913]),
#  (u'Luxury,Other,SpFlash,Unione', [6]),
#  (u'APlusFlash,CommercialPremium,Luxury,Unione', [6]),
#  (u'Carpool,CommercialPremium,Unione,YouXiang', [55]),
#  (u'Flash,Premium,YouXiang', [365550]),
#  (u'APlusFlash,Flash,Premium,SpFlash,YouXiang', [20730]),
#  (u'Luxury,SpFlash,Unione,YouXiang', [11]),
#  (u'APlusFlash,Carpool,Luxury,Other,Premium,SpFlash', [2]),
#  (u'CommercialPremium,Flash,Other,Premium,SpFlash,Unione,YouXiang', [1842]),
#  (u'Flash,Luxury,YouXiang', [518]),
#  (u'Flash,Other,SpFlash,Unione', [561895]),
#  (u'APlusFlash,Carpool,CommercialPremium,Premium,SpFlash,Unione,YouXiang',
#   [50]),
#  (u'APlusFlash,Other,Premium,Unione,YouXiang', [3044]),
#  (u'CommercialPremium,Flash,Other,Premium,SpFlash,YouXiang', [364]),
#  (u'CommercialPremium,Flash,Luxury,Premium,YouXiang', [202]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Premium,SpFlash,YouXiang', [1]),
#  (u'CommercialPremium,Flash,Other,Unione,YouXiang', [219]),
#  (u'Carpool,CommercialPremium,Other,Premium,SpFlash,Unione', [58]),
#  (u'YouXiang', [1300208]),
#  (u'Carpool,CommercialPremium,Luxury,Other,SpFlash,Unione,YouXiang', [2]),
#  (u'CommercialPremium,Flash,Premium,SpFlash,Unione,YouXiang', [2322]),
#  (u'Flash,Luxury,Other', [130]),
#  (u'APlusFlash,Carpool,SpFlash,Unione', [132232]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Other,Unione', [2]),
#  (u'APlusFlash,CommercialPremium,Flash,Premium,SpFlash,Unione,YouXiang',
#   [783]),
#  (u'Carpool,Other,Unione', [124405]),
#  (u'Carpool,Other,Premium,Unione', [2988]),
#  (u'Carpool,Flash,Luxury,Premium,Unione', [21]),
#  (u'Carpool,Flash,Unione', [243325]),
#  (u'APlusFlash,CommercialPremium,YouXiang', [204]),
#  (u'Luxury,Premium,SpFlash,YouXiang', [93]),
#  (u'APlusFlash,Flash,Other,Unione,YouXiang', [123958]),
#  (u'Carpool,Other,SpFlash', [506759]),
#  (u'Carpool,Flash,Other,Unione', [28387]),
#  (u'Flash,Luxury,SpFlash,Unione', [172]),
#  (u'Flash,SpFlash,Unione', [2206204]),
#  (u'APlusFlash,CommercialPremium,Premium,Unione', [397]),
#  (u'APlusFlash,Carpool,Flash,Other,Unione,YouXiang', [3319]),
#  (u'APlusFlash,Carpool,Luxury,Premium,Unione', [1]),
#  (u'APlusFlash,Carpool,Luxury,SpFlash,Unione,YouXiang', [2]),
#  (u'Flash', [46106056]),
#  (u'Other,Premium,SpFlash,Unione', [5316]),
#  (u'APlusFlash,Carpool,Flash,Premium,SpFlash,Unione', [1116]),
#  (u'APlusFlash,Carpool,SpFlash,Unione,YouXiang', [10110]),
#  (u'APlusFlash,CommercialPremium,Other,YouXiang', [19]),
#  (u'APlusFlash,CommercialPremium,Flash,Other,Premium,YouXiang', [271]),
#  (u'APlusFlash,Carpool,CommercialPremium,Luxury,Other,Premium,Unione,YouXiang',
#   [19]),
#  (u'CommercialPremium,Premium,SpFlash,YouXiang', [267]),
#  (u'CommercialPremium,Luxury,Other,Premium,YouXiang', [99]),
#  (u'Carpool,Unione', [753116]),
#  (u'Carpool,Flash,Luxury', [30]),
#  (u'Carpool,Flash,Luxury,Premium,SpFlash,YouXiang', [23]),
#  (u'Carpool,Luxury,Other,SpFlash', [14]),
#  (u'Premium,SpFlash,Unione,YouXiang', [7463]),
#  (u'APlusFlash,CommercialPremium,Flash,Other,YouXiang', [39]),
#  (u'Carpool,SpFlash,Unione,YouXiang', [64944]),
#  (u'APlusFlash,Flash,Luxury,Other,SpFlash,Unione,YouXiang', [14]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Other,Unione,YouXiang', [2]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Other,SpFlash', [3]),
#  (u'Carpool,Luxury,Other,Unione', [23]),
#  (u'APlusFlash,CommercialPremium,Other,Premium,SpFlash', [61]),
#  (u'APlusFlash,Carpool,Other,SpFlash,YouXiang', [8496]),
#  (u'Carpool,Flash,Premium,Unione,YouXiang', [20068]),
#  (u'APlusFlash,Carpool,Flash,Premium,SpFlash,Unione,YouXiang', [2082]),
#  (u'Carpool,CommercialPremium,Flash,Premium,Unione', [5]),
#  (u'APlusFlash,Luxury,Premium,SpFlash,Unione,YouXiang', [2]),
#  (u'APlusFlash,CommercialPremium,Luxury,SpFlash,YouXiang', [1]),
#  (u'APlusFlash,CommercialPremium,Other,Premium,SpFlash,Unione,YouXiang', [75]),
#  (u'Luxury,SpFlash,Unione', [36]),
#  (u'APlusFlash,Other,Premium,SpFlash,YouXiang', [1704]),
#  (u'APlusFlash,Premium,SpFlash,Unione,YouXiang', [2071]),
#  (u'Carpool,Flash,Other,Unione,YouXiang', [13187]),
#  (u'CommercialPremium,Flash,Luxury,Premium,SpFlash,Unione,YouXiang', [233]),
#  (u'APlusFlash,CommercialPremium,Flash,Other,SpFlash', [242]),
#  (u'APlusFlash,Flash,Luxury,Other,Premium,YouXiang', [74]),
#  (u'Premium,Unione', [112810]),
#  (u'Carpool,CommercialPremium,Flash,Unione', [9]),
#  (u'APlusFlash,Carpool,CommercialPremium,Other,Unione', [9]),
#  (u'Carpool,SpFlash,YouXiang', [87398]),
#  (u'Carpool,Other,YouXiang', [26074]),
#  (u'Carpool,Flash,Other,Premium,YouXiang', [527]),
#  (u'SpFlash,YouXiang', [162235]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash', [3]),
#  (u'APlusFlash,Carpool,Flash,Premium,Unione,YouXiang', [6106]),
#  (u'Carpool,CommercialPremium,Other,Premium,SpFlash,Unione,YouXiang', [263]),
#  (u'Luxury,Other,YouXiang', [18]),
#  (u'APlusFlash,Carpool,Flash,Other,SpFlash,Unione', [8255]),
#  (u'APlusFlash,Flash,Luxury,YouXiang', [38]),
#  (u'Carpool,Flash,Other,YouXiang', [5129]),
#  (u'APlusFlash,Carpool,CommercialPremium,Luxury,Other,Premium,SpFlash,Unione,YouXiang',
#   [27]),
#  (u'Flash,Premium,SpFlash,Unione', [33974]),
#  (u'Carpool,Flash,Other,Premium,SpFlash,Unione,YouXiang', [1964]),
#  (u'Carpool,Flash,Premium,YouXiang', [7728]),
#  (u'APlusFlash,Carpool,Luxury,Premium', [8]),
#  (u'APlusFlash,Carpool,Luxury,Other,Premium', [1]),
#  (u'Luxury,Premium,Unione,YouXiang', [650]),
#  (u'Carpool,CommercialPremium,Flash,SpFlash,Unione,YouXiang', [3]),
#  (u'Carpool,Flash,Luxury,Other,Premium,SpFlash', [1]),
#  (u'Other,Premium,YouXiang', [18412]),
#  (u'Flash,Luxury,Premium,Unione', [419]),
#  (u'APlusFlash,Flash,Other,SpFlash,YouXiang', [74887]),
#  (u'Carpool,Flash,Luxury,Premium,Unione,YouXiang', [878]),
#  (u'APlusFlash,Luxury,Other,Premium,YouXiang', [39]),
#  (u'APlusFlash,CommercialPremium,Luxury,Other,Premium,SpFlash,YouXiang', [4]),
#  (u'Carpool,CommercialPremium,Flash,Other,Premium,SpFlash,Unione', [7]),
#  (u'Carpool,Flash,Other', [32620]),
#  (u'Carpool,CommercialPremium,Flash,YouXiang', [1]),
#  (u'APlusFlash,Carpool,Flash,Other,SpFlash', [4329]),
#  (u'Carpool,Flash,Luxury,Other,SpFlash,YouXiang', [3]),
#  (u'Carpool,CommercialPremium,Flash,Premium,SpFlash,YouXiang', [6]),
#  (u'Carpool,Luxury,Premium,SpFlash,YouXiang', [29]),
#  (u'APlusFlash,Luxury,Other,Premium,Unione,YouXiang', [20]),
#  (u'Carpool,Flash,Luxury,Unione', [47]),
#  (u'APlusFlash,Flash,Luxury,Other,Premium,SpFlash,Unione', [7]),
#  (u'APlusFlash,Flash,Other,SpFlash,Unione', [296350]),
#  (u'CommercialPremium,Flash,Luxury,Other,Premium,SpFlash,Unione', [40]),
#  (u'Flash,Premium,Unione,YouXiang', [277891]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Other,SpFlash', [1]),
#  (u'APlusFlash,Flash,Luxury,SpFlash', [22]),
#  (u'Carpool,CommercialPremium,Other,Unione', [12]),
#  (u'APlusFlash,Carpool,Luxury,SpFlash', [5]),
#  (u'Carpool,CommercialPremium,SpFlash,Unione', [62]),
#  (u'APlusFlash,Carpool,SpFlash,YouXiang', [13051]),
#  (u'APlusFlash,Carpool,CommercialPremium,Other,Premium,YouXiang', [4]),
#  (u'CommercialPremium,Flash,Luxury,Premium,SpFlash', [30]),
#  (u'APlusFlash,Carpool,Luxury', [10]),
#  (u'Carpool,Luxury,Other,Premium,Unione,YouXiang', [62]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Premium,SpFlash,Unione', [12]),
#  (u'CommercialPremium,Luxury,Other,Premium,SpFlash', [5]),
#  (u'CommercialPremium,Flash,Premium,SpFlash', [458]),
#  (u'APlusFlash,CommercialPremium,Luxury,Other,Premium,SpFlash,Unione,YouXiang',
#   [7]),
#  (u'APlusFlash,Carpool,Premium,SpFlash', [2927]),
#  (u'Luxury,YouXiang', [563]),
#  (u'Flash,Premium,SpFlash,Unione,YouXiang', [86362]),
#  (u'APlusFlash,CommercialPremium,Luxury,Other,Premium,YouXiang', [6]),
#  (u'Carpool,CommercialPremium,Flash,Other,SpFlash', [1]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Premium,SpFlash,Unione,YouXiang',
#   [66]),
#  (u'Carpool,Luxury,Other', [24]),
#  (u'Carpool,Flash,Luxury,Premium,YouXiang', [47]),
#  (u'CommercialPremium', [166861]),
#  (u'Carpool,Other,Premium', [4637]),
#  (u'APlusFlash,CommercialPremium,Flash,Other,Unione,YouXiang', [63]),
#  (u'Carpool,CommercialPremium,Flash,Luxury,Premium,Unione,YouXiang', [16]),
#  (u'APlusFlash,Carpool,Flash,Other,Premium,Unione,YouXiang', [2540]),
#  (u'Luxury,Other', [139]),
#  (u'CommercialPremium,Flash,Luxury,Premium,Unione', [64]),
#  (u'APlusFlash,Unione,YouXiang', [33150]),
#  (u'Flash,SpFlash', [10943950]),
#  (u'APlusFlash,CommercialPremium,Luxury,SpFlash,Unione', [1]),
#  (u'CommercialPremium,Flash,Luxury,Other,Premium,SpFlash,Unione,YouXiang',
#   [254]),
#  (u'Flash,Other,Premium', [29129]),
#  (u'Carpool,CommercialPremium,Flash,Other,Premium,Unione,YouXiang', [7]),
#  (u'CommercialPremium,Flash,Luxury,Other,SpFlash', [5]),
#  (u'Carpool,Flash,Luxury,Other,SpFlash,Unione,YouXiang', [15]),
#  (u'APlusFlash,Carpool,Flash,Other,Premium,Unione', [887]),
#  (u'Carpool,CommercialPremium,Other,SpFlash,YouXiang', [13]),
#  (u'Carpool,Flash,SpFlash,Unione,YouXiang', [27044]),
#  (u'CommercialPremium,Flash,SpFlash', [4480]),
#  (u'Carpool,CommercialPremium,Flash,Premium', [4]),
#  (u'CommercialPremium,Other,SpFlash,Unione', [123]),
#  (u'Carpool,CommercialPremium,Flash,Premium,YouXiang', [10]),
#  (u'CommercialPremium,Luxury,SpFlash,Unione', [2]),
#  (u'APlusFlash,Luxury,Premium,SpFlash,Unione', [2]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,SpFlash,Unione', [4]),
#  (u'CommercialPremium,Luxury,Other', [26]),
#  (u'Flash,Luxury,SpFlash,Unione,YouXiang', [249]),
#  (u'Carpool,CommercialPremium,Premium,SpFlash', [31]),
#  (u'APlusFlash,Other,SpFlash,YouXiang', [8038]),
#  (u'Luxury,Other,Premium,SpFlash,YouXiang', [5]),
#  (u'APlusFlash,Carpool,Flash,Luxury,Premium,SpFlash,Unione,YouXiang', [3]),
#  (u'APlusFlash,Carpool,YouXiang', [22218]),
#  (u'CommercialPremium,Flash,Premium,SpFlash,Unione', [305]),
#  (u'Flash,Luxury,Other,Premium,Unione,YouXiang', [693]),
#  (u'APlusFlash,Luxury,Other,SpFlash,Unione', [1]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury', [11]),
#  (u'Flash,YouXiang', [3268753]),
#  (u'Carpool,Luxury,Other,SpFlash,Unione', [7]),
#  (u'CommercialPremium,Luxury,Other,Unione,YouXiang', [1]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Luxury,Other,Premium,SpFlash,Unione',
#   [4]),
#  (u'Other,Unione,YouXiang', [23922]),
#  (u'Carpool,CommercialPremium,Luxury,Unione', [3]),
#  (u'Carpool,CommercialPremium,Luxury,Premium,SpFlash,Unione,YouXiang', [31]),
#  (u'APlusFlash,CommercialPremium,Other,SpFlash,Unione', [35]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Other,Premium', [1]),
#  (u'CommercialPremium,Premium,SpFlash', [577]),
#  (u'APlusFlash,CommercialPremium,Luxury,Other', [2]),
#  (u'APlusFlash,CommercialPremium,SpFlash,Unione', [53]),
#  (u'CommercialPremium,Other,Premium,YouXiang', [754]),
#  (u'Flash,Other,Premium,Unione', [21494]),
#  (u'Carpool,Flash,Luxury,Other,Premium,Unione,YouXiang', [69]),
#  (u'APlusFlash,Flash,Premium,Unione,YouXiang', [67727]),
#  (u'Flash,Luxury,Other,Premium', [74]),
#  (u'APlusFlash,CommercialPremium,Flash,Premium,SpFlash,YouXiang', [283]),
#  (u'APlusFlash,Carpool,Luxury,Other,Premium,Unione,YouXiang', [19]),
#  (u'Carpool,Flash,Luxury,Other,Premium,SpFlash,YouXiang', [6]),
#  (u'Other,YouXiang', [58207]),
#  (u'APlusFlash,Flash,Luxury,Other,Unione,YouXiang', [29]),
#  (u'APlusFlash,Carpool,Flash,Premium,Unione', [3944]),
#  (u'APlusFlash,Luxury,Premium', [259]),
#  (u'APlusFlash,Carpool,CommercialPremium,Premium,SpFlash,YouXiang', [18]),
#  (u'APlusFlash,CommercialPremium,Flash,Unione', [506]),
#  (u'Carpool,Flash,Luxury,YouXiang', [40]),
#  (u'Carpool,Flash,Other,SpFlash,YouXiang', [3196]),
#  (u'APlusFlash,Other,Unione', [23567]),
#  (u'APlusFlash,Carpool,CommercialPremium,SpFlash,YouXiang', [13]),
#  (u'Flash,Luxury,Other,Unione,YouXiang', [86]),
#  (u'Flash,Luxury,Other,SpFlash', [40]),
#  (u'APlusFlash,Carpool,Other,Unione', [42193]),
#  (u'APlusFlash,Flash,Luxury,Other,SpFlash', [7]),
#  (u'Carpool,Flash,Luxury,Other,Unione', [4]),
#  (u'APlusFlash,Carpool,CommercialPremium,Other,Premium', [6]),
#  (u'APlusFlash,Flash,Luxury,Premium,Unione', [114]),
#  (u'Carpool,CommercialPremium,Luxury,Other,Premium,Unione', [3]),
#  (u'Flash,Luxury,Other,SpFlash,Unione', [23]),
#  (u'APlusFlash,Carpool,Flash,SpFlash', [37258]),
#  (u'Flash,Luxury,Premium,SpFlash,Unione', [84]),
#  (u'APlusFlash,Carpool,Flash,Luxury,Other,Premium,SpFlash,Unione,YouXiang',
#   [1]),
#  (u'Flash,Other,SpFlash', [1628113]),
#  (u'APlusFlash,Flash,Luxury,Other,YouXiang', [12]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Unione', [3]),
#  (u'Unione', [7291611]),
#  (u'APlusFlash,Flash,Luxury,Other,Premium,SpFlash,YouXiang', [7]),
#  (u'APlusFlash,YouXiang', [94825]),
#  (u'Carpool,Premium,SpFlash,Unione', [4284]),
#  (u'APlusFlash,CommercialPremium,Luxury,Premium,Unione', [25]),
#  (u'Flash,Luxury,Other,YouXiang', [64]),
#  (u'Carpool,Flash,Luxury,Other,SpFlash', [5]),
#  (u'Luxury,Other,Premium', [135]),
#  (u'Carpool,CommercialPremium,Luxury,Premium,SpFlash,Unione', [6]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Unione', [7]),
#  (u'CommercialPremium,Luxury,Premium,Unione,YouXiang', [141]),
#  (u'APlusFlash,CommercialPremium,Premium', [1068]),
#  (u'APlusFlash,Luxury,Premium,SpFlash,YouXiang', [4]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,SpFlash,Unione', [4]),
#  (u'Carpool,CommercialPremium,Other,Premium,Unione,YouXiang', [80]),
#  (u'CommercialPremium,Flash,Luxury,Other,SpFlash,Unione', [10]),
#  (u'APlusFlash,Carpool,Flash,Unione', [150646]),
#  (u'Premium,YouXiang', [446453]),
#  (u'APlusFlash,Flash,Luxury,Premium', [178]),
#  (u'APlusFlash,Carpool,Flash,Premium', [679]),
#  (u'CommercialPremium,Premium,YouXiang', [7421]),
#  (u'APlusFlash,Other,SpFlash', [79964]),
#  (u'Flash,Other,Unione', [672356]),
#  (u'CommercialPremium,Flash,Premium,YouXiang', [3060]),
#  (u'APlusFlash,CommercialPremium,Other,Premium,Unione,YouXiang', [83]),
#  (u'CommercialPremium,Luxury,Other,Premium,Unione', [6]),
#  (u'APlusFlash,Luxury,Other', [9]),
#  (u'CommercialPremium,Luxury,Other,Premium,Unione,YouXiang', [29]),
#  (u'APlusFlash,Carpool,CommercialPremium,YouXiang', [21]),
#  (u'CommercialPremium,Luxury,Other,SpFlash', [2]),
#  (u'APlusFlash,CommercialPremium,Flash,Other,Premium,SpFlash,YouXiang', [355]),
#  (u'Carpool,CommercialPremium,SpFlash,YouXiang', [32]),
#  (u'APlusFlash,Premium,SpFlash,Unione', [3237]),
#  (u'APlusFlash,Other,Premium,SpFlash,Unione,YouXiang', [1108]),
#  (u'APlusFlash,Carpool,CommercialPremium,Luxury,Premium,Unione,YouXiang', [3]),
#  (u'APlusFlash,Flash,Luxury,Other,Premium,SpFlash,Unione,YouXiang', [43]),
#  (u'CommercialPremium,Flash,Luxury,Premium,Unione,YouXiang', [265]),
#  (u'APlusFlash,Carpool,CommercialPremium,Other,SpFlash', [26]),
#  (u'Carpool,CommercialPremium,Luxury,Other,Premium,Unione,YouXiang', [11]),
#  (u'Carpool,CommercialPremium,Flash,Other,Premium,SpFlash,Unione,YouXiang',
#   [27]),
#  (u'APlusFlash,CommercialPremium,Flash', [1437]),
#  (u'CommercialPremium,Flash,Luxury,Other,Unione,YouXiang', [7]),
#  (u'CommercialPremium,Flash,Luxury,Unione', [21]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Other,Premium,SpFlash,Unione',
#   [126]),
#  (u'CommercialPremium,Flash,Luxury,Other,Premium,Unione,YouXiang', [313]),
#  (u'APlusFlash,Carpool,Flash,SpFlash,YouXiang', [2019]),
#  (u'CommercialPremium,SpFlash,Unione,YouXiang', [46]),
#  (u'APlusFlash,Carpool,CommercialPremium,Premium,Unione,YouXiang', [33]),
#  (u'APlusFlash,Carpool,CommercialPremium,Other,Premium,SpFlash,Unione', [289]),
#  (u'Flash,Luxury,SpFlash', [222]),
#  (u'APlusFlash,Carpool,Premium,SpFlash,YouXiang', [1125]),
#  (u'APlusFlash,Luxury,Other,Unione,YouXiang', [3]),
#  (u'APlusFlash,Flash,Luxury,SpFlash,YouXiang', [8]),
#  (u'Carpool,Flash,Luxury,Premium', [9]),
#  (u'APlusFlash,Carpool,Luxury,Other,Premium,SpFlash,Unione', [5]),
#  (u'Carpool,Flash,SpFlash', [188583]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Other,Premium,Unione', [8]),
#  (u'APlusFlash,Flash,Luxury,Premium,YouXiang', [156]),
#  (u'APlusFlash,Flash,Premium,Unione', [69196]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,SpFlash', [6]),
#  (u'CommercialPremium,Luxury,Other,YouXiang', [2]),
#  (u'CommercialPremium,Flash,Premium', [2599]),
#  (u'CommercialPremium,Other,Premium', [4472]),
#  (u'Carpool,Flash,Luxury,Premium,SpFlash,Unione,YouXiang', [390]),
#  (u'CommercialPremium,Flash,YouXiang', [2101]),
#  (u'Carpool,Flash,Premium,SpFlash,Unione', [876]),
#  (u'APlusFlash,Other,SpFlash,Unione,YouXiang', [4555]),
#  (u'CommercialPremium,Luxury,Unione,YouXiang', [6]),
#  (u'Carpool,Luxury,Premium,SpFlash', [8]),
#  (u'APlusFlash,CommercialPremium,Flash,Other', [106]),
#  (u'Carpool,CommercialPremium,Flash,Other,Premium,SpFlash', [2]),
#  (u'Carpool,Luxury,Premium,SpFlash,Unione', [9]),
#  (u'Luxury,Other,Unione', [27]),
#  (u'APlusFlash,Carpool,CommercialPremium,Luxury,Other,Premium', [7]),
#  (u'APlusFlash,CommercialPremium,Luxury,Other,Premium,SpFlash', [3]),
#  (u'APlusFlash,Carpool,Luxury,Other,Premium,Unione', [22]),
#  (u'Carpool,Flash,Luxury,SpFlash,YouXiang', [34]),
#  (u'APlusFlash,CommercialPremium,Luxury,Premium,SpFlash,YouXiang', [2]),
#  (u'CommercialPremium,Flash,Luxury,SpFlash,Unione,YouXiang', [5]),
#  (u'Carpool,Luxury,Other,Premium,SpFlash,YouXiang', [11]),
#  (u'APlusFlash,Carpool,Flash,Other,SpFlash,YouXiang', [584]),
#  (u'APlusFlash,Carpool,CommercialPremium,Flash,Other,Premium', [1]),
#  (u'APlusFlash,Carpool,CommercialPremium,Unione', [37]),
#  (u'Premium,SpFlash,Unione', [12037]),
#  (u'Carpool,CommercialPremium,Luxury,Premium,YouXiang', [5]),
#  (u'Carpool,Luxury,Other,Premium,SpFlash,Unione,YouXiang', [60]),
#  (u'Carpool,CommercialPremium,Flash,Luxury,Other,Premium,Unione,YouXiang',
#   [5]),
#  (u'Luxury,Premium,Unione', [628]),
#  (u'Luxury,Unione,YouXiang', [92]),
#  (u'Flash,Luxury,Other,Premium,SpFlash,YouXiang', [41]),
#  (u'APlusFlash,Carpool,Luxury,Other,Unione,YouXiang', [3]),
#  (u'Carpool,CommercialPremium,Premium,Unione', [49]),
#  (u'CommercialPremium,Flash,Luxury,Premium,SpFlash,YouXiang', [85]),
#  (u'Carpool,CommercialPremium,Flash,Luxury,Other,Premium,SpFlash,Unione,YouXiang',
#   [10]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Premium,SpFlash', [6]),
#  (u'CommercialPremium,Premium,SpFlash,Unione', [75]),
#  (u'APlusFlash,CommercialPremium,Flash,Premium,YouXiang', [531]),
#  (u'APlusFlash,Carpool,Premium', [4635]),
#  (u'Carpool,Other,Premium,YouXiang', [1500]),
#  (u'APlusFlash,Luxury,Premium,Unione', [102]),
#  (u'APlusFlash,CommercialPremium,SpFlash,YouXiang', [41]),
#  (u'CommercialPremium,Flash,Luxury,Other,YouXiang', [10]),
#  (u'APlusFlash,Carpool,Flash,Other,SpFlash,Unione,YouXiang', [1362]),
#  (u'APlusFlash,Carpool,Flash,SpFlash,Unione,YouXiang', [3154]),
#  (u'APlusFlash,CommercialPremium,Other,SpFlash,Unione,YouXiang', [21]),
#  (u'CommercialPremium,Flash,Premium,Unione,YouXiang', [2685]),
#  (u'Carpool,CommercialPremium,Other,Premium,SpFlash', [22]),
#  (u'Carpool,Luxury,Premium,YouXiang', [56]),
#  (u'CommercialPremium,Luxury,Other,Premium,SpFlash,Unione,YouXiang', [18]),
#  (u'Flash,Luxury,Premium,SpFlash,Unione,YouXiang', [1071]),
#  (u'CommercialPremium,Luxury,Premium,SpFlash,Unione', [7]),
#  (u'APlusFlash,Carpool,Luxury,Other,SpFlash,Unione', [1]),
#  (u'APlusFlash,Flash,SpFlash,Unione,YouXiang', [100187]),
#  (u'CommercialPremium,Luxury,Premium,SpFlash', [21]),
#  (u'APlusFlash,CommercialPremium,Unione', [214]),
#  (u'CommercialPremium,Other,Premium,SpFlash', [159]),
#  (u'Carpool,Luxury,SpFlash,Unione', [35]),
#  (u'APlusFlash,Flash,Other,Premium', [12672]),
#  (u'APlusFlash,Carpool,Premium,SpFlash,Unione,YouXiang', [2475]),
#  (u'APlusFlash,Flash,Other,Premium,Unione', [21252]),
#  (u'APlusFlash,Carpool,Flash,Unione,YouXiang', [7971]),
#  (u'CommercialPremium,Luxury,Premium,SpFlash,Unione,YouXiang', [18]),
#  (u'CommercialPremium,Flash,Luxury,Other,Premium,SpFlash,YouXiang', [51]),
#  (u'Other,SpFlash,Unione,YouXiang', [9980]),
#  (u'APlusFlash,Luxury,Other,Premium,SpFlash', [5]),
#  (u'Carpool,Flash,Other,Premium,SpFlash,Unione', [252]),
#  (u'APlusFlash,Carpool,CommercialPremium', [78]),
#  (u'Carpool,CommercialPremium,Flash,Luxury,Premium,SpFlash,Unione,YouXiang',
#   [18]),
#  (u'APlusFlash,CommercialPremium,Flash,Premium,SpFlash', [208]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Other,Premium,Unione', [41]),
#  (u'APlusFlash,CommercialPremium,Flash,Luxury,Other,SpFlash,Unione,YouXiang',
#   [2]),
#  (u'APlusFlash,Carpool,CommercialPremium,SpFlash,Unione,YouXiang', [7]),
#  (u'APlusFlash,CommercialPremium,Other,SpFlash', [90]),
#  (u'Flash,SpFlash,Unione,YouXiang', [473467]),
#  (u'CommercialPremium,Flash,Luxury,Other,Unione', [5]),
#  (u'APlusFlash,Flash,Premium,SpFlash,Unione,YouXiang', [20926]),
#  (u'APlusFlash,Carpool,CommercialPremium,Luxury,Premium,SpFlash,Unione,YouXiang',
#   [14]),
#  (u'APlusFlash,Carpool,CommercialPremium,Premium,SpFlash,Unione', [76]),
#  (u'Carpool,Flash', [826770]),
#  (u'Flash,Luxury,Unione', [519]),
#  (u'APlusFlash,Carpool,CommercialPremium,Luxury,Premium,SpFlash,Unione', [2]),
#  (u'CommercialPremium,Other,YouXiang', [105]),
#  (u'Flash,Luxury,Premium,SpFlash', [110]),
#  (u'APlusFlash,Carpool,CommercialPremium,Other,Premium,Unione,YouXiang', [54]),
#  (u'APlusFlash,Carpool,CommercialPremium,Luxury,Premium', [1]),
#  (u'APlusFlash,Other', [46642]),
#  (u'SpFlash,Unione,YouXiang', [33152]),
#  (u'APlusFlash,Carpool,CommercialPremium,Luxury,Other,Premium,SpFlash,Unione',
#   [35]),
#  (u'APlusFlash,Carpool,Unione', [159217]),
#  (u'CommercialPremium,Luxury,Premium,YouXiang', [539]),
#  (u'CommercialPremium,Other,SpFlash,Unione,YouXiang', [19]),
#  (u'Carpool,CommercialPremium,Flash,Luxury,Premium,YouXiang', [1]),
#  (u'APlusFlash,Flash,Other,SpFlash,Unione,YouXiang', [84460]),
#  (u'Flash,Luxury,Other,Premium,Unione', [160]),
#  (u'CommercialPremium,Other,Unione,YouXiang', [40])]

# %%
len(rst)
# Out:
# 867

# %%
def to_pandas(data):
    rst = pd.DataFrame([v for v in data])
    rst.columns = [
        "product_set",
        "call_num"
    ]
    return rst

# %%
rst_pd = to_pandas(rst)

# %%
rst_pd
# Out:
#                                            product_set    call_num
# 0              CommercialPremium,Luxury,Premium,Unione       [155]
# 1       Carpool,Luxury,Premium,SpFlash,Unione,YouXiang       [197]
# 2    APlusFlash,Carpool,CommercialPremium,Flash,Oth...         [1]
# 3    CommercialPremium,Flash,Other,Premium,Unione,Y...      [1849]
# 4    CommercialPremium,Flash,Other,Premium,SpFlash,...       [287]
# 5                    APlusFlash,Flash,Premium,YouXiang     [79073]
# 6    APlusFlash,Carpool,CommercialPremium,Flash,Lux...         [1]
# 7               CommercialPremium,Flash,Other,YouXiang       [250]
# 8         APlusFlash,Carpool,CommercialPremium,SpFlash        [35]
# 9                   APlusFlash,Carpool,Luxury,YouXiang         [6]
# 10   APlusFlash,Carpool,CommercialPremium,Flash,Oth...        [27]
# 11   APlusFlash,Carpool,CommercialPremium,Flash,Lux...         [1]
# 12    Carpool,CommercialPremium,Luxury,Premium,SpFlash         [6]
# 13           Carpool,Flash,Luxury,Other,SpFlash,Unione         [4]
# 14     APlusFlash,Flash,Luxury,Premium,Unione,YouXiang       [154]
# 15              CommercialPremium,Flash,Luxury,Premium       [158]
# 16                         Flash,Other,Premium,SpFlash     [23596]
# 17                    Carpool,CommercialPremium,Unione       [144]
# 18             APlusFlash,Carpool,Other,SpFlash,Unione     [59162]
# 19                     CommercialPremium,Luxury,Unione        [32]
# 20                 Flash,Other,Premium,Unione,YouXiang     [47493]
# 21   APlusFlash,CommercialPremium,Luxury,Premium,Sp...         [1]
# 22   CommercialPremium,Other,Premium,SpFlash,Unione...        [62]
# 23                                             SpFlash  [12934641]
# 24    CommercialPremium,Flash,Premium,SpFlash,YouXiang      [1179]
# 25   APlusFlash,Carpool,Other,Premium,SpFlash,Union...      [3716]
# 26   CommercialPremium,Luxury,Other,Premium,SpFlash...         [2]
# 27                   Carpool,CommercialPremium,Premium       [175]
# 28          APlusFlash,CommercialPremium,Other,Premium       [359]
# 29   APlusFlash,CommercialPremium,Flash,Other,Premi...       [242]
# ..                                                 ...         ...
# 837         Carpool,Flash,Other,Premium,SpFlash,Unione       [252]
# 838               APlusFlash,Carpool,CommercialPremium        [78]
# 839  Carpool,CommercialPremium,Flash,Luxury,Premium...        [18]
# 840  APlusFlash,CommercialPremium,Flash,Premium,SpF...       [208]
# 841  APlusFlash,CommercialPremium,Flash,Luxury,Othe...        [41]
# 842  APlusFlash,CommercialPremium,Flash,Luxury,Othe...         [2]
# 843  APlusFlash,Carpool,CommercialPremium,SpFlash,U...         [7]
# 844         APlusFlash,CommercialPremium,Other,SpFlash        [90]
# 845                      Flash,SpFlash,Unione,YouXiang    [473467]
# 846        CommercialPremium,Flash,Luxury,Other,Unione         [5]
# 847   APlusFlash,Flash,Premium,SpFlash,Unione,YouXiang     [20926]
# 848  APlusFlash,Carpool,CommercialPremium,Luxury,Pr...        [14]
# 849  APlusFlash,Carpool,CommercialPremium,Premium,S...        [76]
# 850                                      Carpool,Flash    [826770]
# 851                                Flash,Luxury,Unione       [519]
# 852  APlusFlash,Carpool,CommercialPremium,Luxury,Pr...         [2]
# 853                   CommercialPremium,Other,YouXiang       [105]
# 854                       Flash,Luxury,Premium,SpFlash       [110]
# 855  APlusFlash,Carpool,CommercialPremium,Other,Pre...        [54]
# 856  APlusFlash,Carpool,CommercialPremium,Luxury,Pr...         [1]
# 857                                   APlusFlash,Other     [46642]
# 858                            SpFlash,Unione,YouXiang     [33152]
# 859  APlusFlash,Carpool,CommercialPremium,Luxury,Ot...        [35]
# 860                          APlusFlash,Carpool,Unione    [159217]
# 861          CommercialPremium,Luxury,Premium,YouXiang       [539]
# 862    CommercialPremium,Other,SpFlash,Unione,YouXiang        [19]
# 863  Carpool,CommercialPremium,Flash,Luxury,Premium...         [1]
# 864     APlusFlash,Flash,Other,SpFlash,Unione,YouXiang     [84460]
# 865                  Flash,Luxury,Other,Premium,Unione       [160]
# 866            CommercialPremium,Other,Unione,YouXiang        [40]
#
# [867 rows x 2 columns]

# %%
call_num_list = []
for i in range(len(rst_pd["call_num"].values)):
    call_num_list.append(rst_pd["call_num"].values[i][0])
call_num_list
# Out:
# [155,
#  197,
#  1,
#  1849,
#  287,
#  79073,
#  1,
#  250,
#  35,
#  6,
#  27,
#  1,
#  6,
#  4,
#  154,
#  158,
#  23596,
#  144,
#  59162,
#  32,
#  47493,
#  1,
#  62,
#  12934641,
#  1179,
#  3716,
#  2,
#  175,
#  359,
#  242,
#  437,
#  2,
#  3491,
#  390,
#  4,
#  26,
#  27,
#  28,
#  101,
#  2528,
#  10,
#  105,
#  1,
#  10,
#  22,
#  15,
#  6,
#  1643,
#  85529,
#  65564,
#  86,
#  396409,
#  146592,
#  161,
#  1,
#  5,
#  93060,
#  118,
#  2683,
#  11,
#  2,
#  253422,
#  41,
#  14,
#  28,
#  5,
#  77,
#  2,
#  8,
#  6,
#  2,
#  182,
#  1,
#  577,
#  15280,
#  96,
#  1,
#  1,
#  15148,
#  99,
#  12832,
#  20,
#  4,
#  3,
#  24196,
#  23375,
#  8,
#  1880065,
#  818,
#  62,
#  3,
#  2962,
#  3,
#  109,
#  2327,
#  11,
#  40,
#  1,
#  2,
#  35,
#  240,
#  11354,
#  43921,
#  1,
#  2,
#  206,
#  38,
#  163,
#  96,
#  7052,
#  4,
#  70,
#  32,
#  4186,
#  401,
#  201,
#  64,
#  5,
#  1790,
#  365,
#  312,
#  72,
#  4187,
#  21,
#  19,
#  206488,
#  2,
#  2,
#  8785,
#  9611,
#  3,
#  302859,
#  526,
#  68,
#  33,
#  25,
#  42,
#  318,
#  16,
#  3,
#  31,
#  4,
#  10,
#  8547547,
#  37,
#  3131,
#  12,
#  1,
#  305336,
#  255519,
#  1403482,
#  2069,
#  28963,
#  34,
#  59,
#  6,
#  36086,
#  14,
#  1,
#  47,
#  37295,
#  9407,
#  22847,
#  11,
#  178,
#  15,
#  1,
#  11,
#  3,
#  319863,
#  10,
#  62,
#  40,
#  36,
#  2,
#  1,
#  44,
#  509618,
#  4046,
#  62622,
#  182368,
#  71050,
#  2018,
#  1158,
#  146,
#  682,
#  23,
#  10707,
#  53,
#  2662,
#  8,
#  5209,
#  649,
#  71,
#  2276897,
#  2,
#  1115767,
#  2085,
#  6579,
#  3,
#  10,
#  18846,
#  2,
#  6861,
#  2,
#  53,
#  6,
#  29200,
#  8,
#  82008,
#  79,
#  76,
#  13,
#  68,
#  26,
#  18231,
#  272,
#  5638459,
#  50062,
#  13388,
#  6320,
#  1110,
#  17121,
#  206,
#  7276,
#  3,
#  20,
#  11,
#  141246,
#  351701,
#  8,
#  78,
#  15,
#  148,
#  72,
#  34886,
#  140,
#  4,
#  3864,
#  1315,
#  1065,
#  117,
#  236592,
#  480330,
#  92977,
#  31,
#  21,
#  12965,
#  324419,
#  11,
#  2,
#  2,
#  2,
#  513915,
#  3,
#  5,
#  138751,
#  1878,
#  9,
#  1715703,
#  943,
#  30,
#  13827,
#  9,
#  2138,
#  42,
#  53726,
#  163,
#  15,
#  6,
#  270,
#  7004,
#  308,
#  97529,
#  91267,
#  1,
#  46,
#  22,
#  667,
#  199,
#  1,
#  1226675,
#  43,
#  7,
#  212,
#  11,
#  242,
#  45,
#  2,
#  43,
#  24447,
#  28742,
#  2179280,
#  14,
#  59,
#  2,
#  1,
#  14,
#  11,
#  2,
#  43191,
#  10333,
#  1378,
#  1,
#  36071,
#  15165,
#  1,
#  4,
#  28,
#  10,
#  480,
#  88,
#  16,
#  19,
#  490,
#  34831,
#  385,
#  3,
#  317279,
#  3,
#  2951,
#  648,
#  27,
#  68,
#  265,
#  20,
#  7,
#  49,
#  358195,
#  10,
#  901375,
#  786709,
#  2,
#  657,
#  42487,
#  1,
#  31,
#  325,
#  1,
#  39,
#  3202,
#  15,
#  155,
#  45,
#  1,
#  2813,
#  2,
#  1,
#  367,
#  5,
#  35,
#  36082,
#  74,
#  922,
#  321,
#  3,
#  8428,
#  12,
#  1760145,
#  215,
#  67,
#  37730,
#  172,
#  21,
#  1984,
#  195,
#  730,
#  151910,
#  1,
#  252,
#  7,
#  15,
#  6,
#  866,
#  3,
#  4286,
#  167,
#  21,
#  11,
#  7,
#  5265354,
#  264,
#  53,
#  82,
#  55,
#  2,
#  4775,
#  124749,
#  3,
#  291,
#  236,
#  28430,
#  2423,
#  2,
#  13153,
#  332816,
#  36,
#  46,
#  48,
#  722,
#  107,
#  582,
#  280424,
#  13867,
#  1575,
#  5232,
#  486,
#  171,
#  4,
#  44,
#  25,
#  7598,
#  69939,
#  22,
#  6,
#  4,
#  992,
#  3,
#  1339,
#  1440,
#  10,
#  21126,
#  436,
#  25,
#  90266,
#  14173,
#  477,
#  104,
#  99,
#  7627,
#  28380,
#  1,
#  5,
#  3787,
#  12366,
#  713,
#  3,
#  37,
#  9031,
#  35,
#  178,
#  421,
#  1578,
#  1,
#  5102,
#  13,
#  6,
#  428,
#  2970,
#  40,
#  13,
#  2,
#  3,
#  1,
#  2024,
#  728,
#  186,
#  7059,
#  9,
#  34244,
#  65,
#  2662,
#  14824,
#  8,
#  101986,
#  189,
#  1272,
#  3,
#  179670,
#  3192,
#  3861,
#  3,
#  449,
#  1173,
#  1380,
#  1,
#  316,
#  237,
#  5,
#  1028216,
#  3454,
#  19,
#  108,
#  20,
#  2001941,
#  4899,
#  13,
#  6,
#  512,
#  33,
#  69,
#  16509,
#  913,
#  6,
#  6,
#  55,
#  365550,
#  20730,
#  11,
#  2,
#  1842,
#  518,
#  561895,
#  50,
#  3044,
#  364,
#  202,
#  1,
#  219,
#  58,
#  1300208,
#  2,
#  2322,
#  130,
#  132232,
#  2,
#  783,
#  124405,
#  2988,
#  21,
#  243325,
#  204,
#  93,
#  123958,
#  506759,
#  28387,
#  172,
#  2206204,
#  397,
#  3319,
#  1,
#  2,
#  46106056,
#  5316,
#  1116,
#  10110,
#  19,
#  271,
#  19,
#  267,
#  99,
#  753116,
#  30,
#  23,
#  14,
#  7463,
#  39,
#  64944,
#  14,
#  2,
#  3,
#  23,
#  61,
#  8496,
#  20068,
#  2082,
#  5,
#  2,
#  1,
#  75,
#  36,
#  1704,
#  2071,
#  13187,
#  233,
#  242,
#  74,
#  112810,
#  9,
#  9,
#  87398,
#  26074,
#  527,
#  162235,
#  3,
#  6106,
#  263,
#  18,
#  8255,
#  38,
#  5129,
#  27,
#  33974,
#  1964,
#  7728,
#  8,
#  1,
#  650,
#  3,
#  1,
#  18412,
#  419,
#  74887,
#  878,
#  39,
#  4,
#  7,
#  32620,
#  1,
#  4329,
#  3,
#  6,
#  29,
#  20,
#  47,
#  7,
#  296350,
#  40,
#  277891,
#  1,
#  22,
#  12,
#  5,
#  62,
#  13051,
#  4,
#  30,
#  10,
#  62,
#  12,
#  5,
#  458,
#  7,
#  2927,
#  563,
#  86362,
#  6,
#  1,
#  66,
#  24,
#  47,
#  166861,
#  4637,
#  63,
#  16,
#  2540,
#  139,
#  64,
#  33150,
#  10943950,
#  1,
#  254,
#  29129,
#  7,
#  5,
#  15,
#  887,
#  13,
#  27044,
#  4480,
#  4,
#  123,
#  10,
#  2,
#  2,
#  4,
#  26,
#  249,
#  31,
#  8038,
#  5,
#  3,
#  22218,
#  305,
#  693,
#  1,
#  11,
#  3268753,
#  7,
#  1,
#  4,
#  23922,
#  3,
#  31,
#  35,
#  1,
#  577,
#  2,
#  53,
#  754,
#  21494,
#  69,
#  67727,
#  74,
#  283,
#  19,
#  6,
#  58207,
#  29,
#  3944,
#  259,
#  18,
#  506,
#  40,
#  3196,
#  23567,
#  13,
#  86,
#  40,
#  42193,
#  7,
#  4,
#  6,
#  114,
#  3,
#  23,
#  37258,
#  84,
#  1,
#  1628113,
#  12,
#  3,
#  7291611,
#  7,
#  94825,
#  4284,
#  25,
#  64,
#  5,
#  135,
#  6,
#  7,
#  141,
#  1068,
#  4,
#  4,
#  80,
#  10,
#  150646,
#  446453,
#  178,
#  679,
#  7421,
#  79964,
#  672356,
#  3060,
#  83,
#  6,
#  9,
#  29,
#  21,
#  2,
#  355,
#  32,
#  3237,
#  1108,
#  3,
#  43,
#  265,
#  26,
#  11,
#  27,
#  1437,
#  7,
#  21,
#  126,
#  313,
#  2019,
#  46,
#  33,
#  289,
#  222,
#  1125,
#  3,
#  8,
#  9,
#  5,
#  188583,
#  8,
#  156,
#  69196,
#  6,
#  2,
#  2599,
#  4472,
#  390,
#  2101,
#  876,
#  4555,
#  6,
#  8,
#  106,
#  2,
#  9,
#  27,
#  7,
#  3,
#  22,
#  34,
#  2,
#  5,
#  11,
#  584,
#  1,
#  37,
#  12037,
#  5,
#  60,
#  5,
#  628,
#  92,
#  41,
#  3,
#  49,
#  85,
#  10,
#  6,
#  75,
#  531,
#  4635,
#  1500,
#  102,
#  41,
#  10,
#  1362,
#  3154,
#  21,
#  2685,
#  22,
#  56,
#  18,
#  1071,
#  7,
#  1,
#  100187,
#  21,
#  214,
#  159,
#  35,
#  12672,
#  2475,
#  21252,
#  7971,
#  18,
#  51,
#  9980,
#  5,
#  252,
#  78,
#  18,
#  208,
#  41,
#  2,
#  7,
#  90,
#  473467,
#  5,
#  20926,
#  14,
#  76,
#  826770,
#  519,
#  2,
#  105,
#  110,
#  54,
#  1,
#  46642,
#  33152,
#  35,
#  159217,
#  539,
#  19,
#  1,
#  84460,
#  160,
#  40]

# %%
rst_pd["call_num"] = call_num_list
rst_pd
# Out:
#                                            product_set  call_num
# 0              CommercialPremium,Luxury,Premium,Unione       155
# 1       Carpool,Luxury,Premium,SpFlash,Unione,YouXiang       197
# 2    APlusFlash,Carpool,CommercialPremium,Flash,Oth...         1
# 3    CommercialPremium,Flash,Other,Premium,Unione,Y...      1849
# 4    CommercialPremium,Flash,Other,Premium,SpFlash,...       287
# 5                    APlusFlash,Flash,Premium,YouXiang     79073
# 6    APlusFlash,Carpool,CommercialPremium,Flash,Lux...         1
# 7               CommercialPremium,Flash,Other,YouXiang       250
# 8         APlusFlash,Carpool,CommercialPremium,SpFlash        35
# 9                   APlusFlash,Carpool,Luxury,YouXiang         6
# 10   APlusFlash,Carpool,CommercialPremium,Flash,Oth...        27
# 11   APlusFlash,Carpool,CommercialPremium,Flash,Lux...         1
# 12    Carpool,CommercialPremium,Luxury,Premium,SpFlash         6
# 13           Carpool,Flash,Luxury,Other,SpFlash,Unione         4
# 14     APlusFlash,Flash,Luxury,Premium,Unione,YouXiang       154
# 15              CommercialPremium,Flash,Luxury,Premium       158
# 16                         Flash,Other,Premium,SpFlash     23596
# 17                    Carpool,CommercialPremium,Unione       144
# 18             APlusFlash,Carpool,Other,SpFlash,Unione     59162
# 19                     CommercialPremium,Luxury,Unione        32
# 20                 Flash,Other,Premium,Unione,YouXiang     47493
# 21   APlusFlash,CommercialPremium,Luxury,Premium,Sp...         1
# 22   CommercialPremium,Other,Premium,SpFlash,Unione...        62
# 23                                             SpFlash  12934641
# 24    CommercialPremium,Flash,Premium,SpFlash,YouXiang      1179
# 25   APlusFlash,Carpool,Other,Premium,SpFlash,Union...      3716
# 26   CommercialPremium,Luxury,Other,Premium,SpFlash...         2
# 27                   Carpool,CommercialPremium,Premium       175
# 28          APlusFlash,CommercialPremium,Other,Premium       359
# 29   APlusFlash,CommercialPremium,Flash,Other,Premi...       242
# ..                                                 ...       ...
# 837         Carpool,Flash,Other,Premium,SpFlash,Unione       252
# 838               APlusFlash,Carpool,CommercialPremium        78
# 839  Carpool,CommercialPremium,Flash,Luxury,Premium...        18
# 840  APlusFlash,CommercialPremium,Flash,Premium,SpF...       208
# 841  APlusFlash,CommercialPremium,Flash,Luxury,Othe...        41
# 842  APlusFlash,CommercialPremium,Flash,Luxury,Othe...         2
# 843  APlusFlash,Carpool,CommercialPremium,SpFlash,U...         7
# 844         APlusFlash,CommercialPremium,Other,SpFlash        90
# 845                      Flash,SpFlash,Unione,YouXiang    473467
# 846        CommercialPremium,Flash,Luxury,Other,Unione         5
# 847   APlusFlash,Flash,Premium,SpFlash,Unione,YouXiang     20926
# 848  APlusFlash,Carpool,CommercialPremium,Luxury,Pr...        14
# 849  APlusFlash,Carpool,CommercialPremium,Premium,S...        76
# 850                                      Carpool,Flash    826770
# 851                                Flash,Luxury,Unione       519
# 852  APlusFlash,Carpool,CommercialPremium,Luxury,Pr...         2
# 853                   CommercialPremium,Other,YouXiang       105
# 854                       Flash,Luxury,Premium,SpFlash       110
# 855  APlusFlash,Carpool,CommercialPremium,Other,Pre...        54
# 856  APlusFlash,Carpool,CommercialPremium,Luxury,Pr...         1
# 857                                   APlusFlash,Other     46642
# 858                            SpFlash,Unione,YouXiang     33152
# 859  APlusFlash,Carpool,CommercialPremium,Luxury,Ot...        35
# 860                          APlusFlash,Carpool,Unione    159217
# 861          CommercialPremium,Luxury,Premium,YouXiang       539
# 862    CommercialPremium,Other,SpFlash,Unione,YouXiang        19
# 863  Carpool,CommercialPremium,Flash,Luxury,Premium...         1
# 864     APlusFlash,Flash,Other,SpFlash,Unione,YouXiang     84460
# 865                  Flash,Luxury,Other,Premium,Unione       160
# 866            CommercialPremium,Other,Unione,YouXiang        40
#
# [867 rows x 2 columns]

# %%
rst_pd.to_csv("./rst/xiefei.csv", index=False, header=True, sep=",", encoding="utf-8_sig")
